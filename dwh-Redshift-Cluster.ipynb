# %% [markdown]
# # 1. IMPORT the necessary libraries

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# # NOTE: AWS secret and Access Key are not available in the dwh.cfg for security reasons.
# - To run this code
#     - Create a new IAM user in your AWS account
#     - provide it AdministratorAccess
#     - Take note of the Access Key and secret and enter it in the dwh.cfg
#
# # 2. LOAD DWH Params from a dwh.cfg file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           4
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB         dwh
# 5             DWH_DB_USER     dwhuser
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# # 3. Create clients from IAM, EC2, S3 and Redshift

# %%
import boto3

ec2 = boto3.resource('ec2',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                    )

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                   )

iam = boto3.client('iam',aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET,
                     region_name='us-west-2'
                  )

redshift = boto3.client('redshift',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                       )

# %% [markdown]
# # 4. Check the available sources in the S3 bucket
#
# we can already check if some of the datasets are available in the S3 bucket. Running some of the procedures in the 02-prepare-finstart-data notebook and 03-prepare-additional-datasets notebook are required if some of the datasets are missing.

# %% [markdown]
# ## 4.1. companies.csv dataset
# Companies.csv holds a list of all S&P 500 companies and must be located under: stock_dfs/sp500_companies.csv.
# in case the csv is missing, run the procedures in notebook: 02-prepare-finstart-data.
#
# Ofcourse the S&P500 companies list is dynamic and therefore it can be useful to run the procedure in 02-prepare-finstart-data.

# %%
DbBucket =  s3.Bucket("cda-dend-capstone")
for obj in DbBucket.objects.filter(Prefix="stock_dfs"):
    obj.key
    
if str(obj.key) == ('stock_dfs/sp500_companies.csv'):
    print('resource is available: ' + str(obj))
else:
    print('sp500_companies.csv is not available, run ... ')
# Out:
# resource is available: s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/sp500_companies.csv')

# %% [markdown]
# ## 4.2. Tickers information of the S&P 500 companies
#
# each company's ticker information is retrieved from yahoo and is stored in one CSV per company. the next statement lists the ticker per company in a CSV format if available. Missing tickers or updating information can be simply accomplished by running the located in notebook: 02-prepare-finstart-data.
#
# Note: I suggest to run this notebook until the cluster is up and running. After the the custer is running than you can decide if you want to run the next notebook: 02-prepare-finstart-data. There is no real reason why you must finish the cluster first, but I just prefer a step by step approach.

# %%
for obj in DbBucket.objects.filter(Prefix="stock_dfs/csv"):
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/A.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AAL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AAP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AAPL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ABBV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ABC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ABMD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ABT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ACN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADBE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ADSK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AEE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AEP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AES.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AFL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AGN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AIG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AIV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AIZ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AJG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AKAM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALGN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALLE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ALXN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMAT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMCR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AME.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMGN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AMZN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ANET.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ANSS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ANTM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AON.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AOS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/APA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/APD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/APH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/APTV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ARE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ARNC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ATO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ATVI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AVB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AVGO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AVY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AWK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AXP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/AZO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BAC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BAX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BBT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BBY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BDX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BEN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BF-B.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BHGE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BIIB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BKNG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BLK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BLL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BMY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BRK-B.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BSX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BWA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/BXP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/C.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CAG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CAH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CAT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CBOE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CBRE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CBS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CCI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CCL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CDNS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CDW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CELG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CERN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CFG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CHD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CHRW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CHTR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CINF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CLX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CMA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CMCSA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CME.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CMG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CMI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CMS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CNC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CNP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COST.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/COTY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CPB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CPRI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CPRT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CRM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CSCO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CSX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CTAS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CTL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CTSH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CTVA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CTXS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CVS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CVX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/CXO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/D.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DAL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DFS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DGX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DHI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DHR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DIS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DISCA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DISCK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DISH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DLR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DLTR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DOV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DOW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DRE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DRI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DTE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DUK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DVA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DVN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/DXC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EBAY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ECL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ED.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EFX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EIX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EMN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EMR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EOG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EQIX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EQR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ES.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ESS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ETFC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ETN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ETR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EVRG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EXC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EXPD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EXPE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/EXR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/F.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FANG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FAST.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FBHS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FCX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FDX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FFIV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FIS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FISV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FITB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FLIR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FLS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FLT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FMC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FOX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FOXA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FRC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FRT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FTI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FTNT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/FTV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GILD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GIS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GLW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GOOG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GOOGL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GPC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GPN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GPS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GRMN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/GWW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HAL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HAS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HBAN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HBI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HCA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HCP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HES.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HFC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HIG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HII.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HLT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HOG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HOLX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HON.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HPE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HPQ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HRB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HRL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HSIC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HST.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HSY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/HUM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IBM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ICE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IDXX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IEX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IFF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ILMN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/INCY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/INFO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/INTC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/INTU.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IPG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IPGP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IQV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IRM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ISRG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ITW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/IVZ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JBHT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JCI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JEC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JKHY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JNJ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JNPR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JPM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/JWN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/K.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KEY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KEYS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KHC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KIM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KLAC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KMB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KMI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KMX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KSS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/KSU.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/L.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LDOS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LEG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LEN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LHX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LIN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LKQ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LLY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LMT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LNC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LNT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LOW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LRCX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LUV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/LYB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/M.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MAA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MAC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MAR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MAS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MCD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MCHP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MCK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MCO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MDLZ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MDT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MET.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MGM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MHK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MKC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MKTX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MLM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MMC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MMM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MNST.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MOS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MPC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MRK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MRO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MSCI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MSFT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MSI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MTB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MTD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MU.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MXIM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/MYL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NBL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NCLH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NDAQ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NEE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NEM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NFLX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NKE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NKTR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NLSN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NOC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NOV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NRG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NSC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NTAP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NTRS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NUE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NVDA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NVR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NWL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NWS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/NWSA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/O.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/OKE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/OMC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ORCL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ORLY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/OXY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PAYX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PBCT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PCAR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PEG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PEP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PFE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PFG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PGR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PHM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PKG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PKI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PLD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PNC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PNR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PNW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PPG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PPL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PRGO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PRU.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PSA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PSX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PVH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PWR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PXD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/PYPL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/QCOM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/QRVO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RCL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/REG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/REGN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RHI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RJF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RMD.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ROK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ROL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ROP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ROST.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RSG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/RTN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SBAC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SBUX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SCHW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SEE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SHW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SIVB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SJM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SLB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SLG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SNA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SNPS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SPG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SPGI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SRE.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/STI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/STT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/STX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/STZ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SWK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SWKS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SYF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SYK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SYMC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/SYY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/T.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TAP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TDG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TEL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TFX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TGT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TIF.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TJX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TMO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TMUS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TPR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TRIP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TROW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TRV.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TSCO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TSN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TTWO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TWTR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TXN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/TXT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UAA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UAL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UDR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UHS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ULTA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UNH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UNM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UNP.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UPS.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/URI.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/USB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/UTX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/V.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VAR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VFC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VIAB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VLO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VMC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VNO.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VRSK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VRSN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VRTX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VTR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/VZ.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WAB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WAT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WBA.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WCG.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WDC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WEC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WELL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WFC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WHR.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WLTW.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WMB.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WMT.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WRK.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WU.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/WYNN.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XEC.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XEL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XLNX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XOM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XRAY.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XRX.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/XYL.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/YUM.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ZBH.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ZION.csv')
# s3.ObjectSummary(bucket_name='cda-dend-capstone', key='stock_dfs/csv/ZTS.csv')

# %% [markdown]
# # 5. IAM Role
# - Create an IAM Role that makes Redshift able to access the S3 DBBucket

# %%
from botocore.exceptions import ClientError

#1.1 Create the role, 
try:
    print("1.1 Creating a new IAM Role") 
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    
except Exception as e:
    print(e)
    
    
print("1.2 Attaching Policy")

iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']

print("1.3 Get the IAM role ARN")
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

print(roleArn)
# Out:
# 1.1 Creating a new IAM Role
# An error occurred (EntityAlreadyExists) when calling the CreateRole operation: Role with name dwhRole already exists.
# 1.2 Attaching Policy
# 1.3 Get the IAM role ARN
# arn:aws:iam::983440384925:role/dwhRole

# %% [markdown]
# # 6. Redshift Cluster
# - Create a RedShift Cluster

# %%
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn]  
    )
except Exception as e:
    print(e)

# %% [markdown]
# # 7. Describe the cluster and show the details
# - Run the block of code several times until the cluster status becomes available

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key         Value
# 0  ClusterIdentifier  dwhcluster
# 1  NodeType           dc2.large
# 2  ClusterStatus      creating
# 3  MasterUsername     dwhuser
# 4  DBName             dwh
# 5  VpcId              vpc-6358f11b
# 6  NumberOfNodes      4

# %% [markdown]
# # 8. Get the cluster endpoint and role ARN

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
endpoint = DWH_ENDPOINT
print("DWH_ENDPOINT :: ", endpoint)
print("DWH_ROLE_ARN :: ", roleArn)

# %% [markdown]
# # 9. Open the incoming TCP port to access the cluster endpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)

# %% [markdown]
# # 10. Load the extension SQL and connect to db (postgres)

# %%
# %load_ext sql

# %%
import os 
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string

# %% [markdown]
# # Delete the Cluster
# It's good to clean up resources that you don't need anymore. Delete the cluster with care, there is no way back.
# The command is commented, it's to make sure that you don't delete the cluster by accident

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
#redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!

# %% [markdown]
# # Check the status of the cluster

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
